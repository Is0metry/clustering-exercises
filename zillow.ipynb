# %%
import wrangle_zillow as w
import pandas as pd
from importlib import reload

# %%
reload(w)
df = w.wrangle_zillow()

# %%
reload(w)
df = w.wrangle_zillow(from_sql=True)

# %%
df = w.prep_zillow(df)
df = w.handle_missing_values(df,.7,.7)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/woody/codeup-data-science/clustering-exercises/zillow.ipynb Cell 4 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/woody/codeup-data-science/clustering-exercises/zillow.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> df = w.prep_zillow(df)
#       <a href='vscode-notebook-cell:/Users/woody/codeup-data-science/clustering-exercises/zillow.ipynb#W3sZmlsZQ%3D%3D?line=1'>2</a> df = w.handle_missing_values(df,.7,.7)
#
# File ~/codeup-data-science/clustering-exercises/wrangle_zillow.py:94, in prep_zillow(df)
#      92     if re.match('.*typeid$',c) is not None:
#      93         cols_to_remove.append(str(c))
# ---> 94 df = df.drop(cols_to_remove)
#      95 return df
#
# ...

# %%
# Out:
# Empty DataFrame
# ...

# %%
# Out:
#        parcelid  airconditioningtypeid  architecturalstyletypeid  \
# 1      17052889                    NaN                       NaN
# 2      14186244                    NaN                       NaN
# 3      12177905                    NaN                       NaN
# 4      12095076                    1.0                       NaN
# 5      12069064                    NaN                       NaN
# ...         ...                    ...                       ...
# 52311  11554146                    1.0                       NaN
# 52437  11000655                    NaN                       NaN
# 52439  12773139                    1.0                       NaN
# 52438  17239384                    NaN                       NaN
# 52440  12826780                    NaN                       NaN
#
#        basementsqft  bathroomcnt  bedroomcnt  buildingclasstypeid  \
# 1               NaN          1.0         2.0                  NaN
# ...
