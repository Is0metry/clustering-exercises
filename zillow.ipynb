# %%
import wrangle_zillow as w
import pandas as pd
from importlib import reload

# %%
reload(w)
df = w.wrangle_zillow()

# %%
reload(w)
df = w.wrangle_zillow()
df = w.prep_zillow(df)
df.shape
# Out:
# (77381, 38)

# %%
s = 'log_error'
k = 1.5
# Out:
#    parcel_id  bath_count  bed_count  calc_bath_and_bed  calc_sqft  \
# 0   14297519         3.5          4                3.5       3100
# 1   17052889         1.0          2                1.0       1465
# 2   14186244         2.0          3                2.0       1243
# 3   12177905         3.0          4                3.0       2376
# 4   10887214         3.0          3                3.0       1312
#
#    finished_sqft12  fips  fireplace_cnt  full_bath_cnt  garage_car_count  ...  \
# 0             3100  6059           <NA>              3                 2  ...
# 1             1465  6111              1              1                 1  ...
# 2             1243  6059           <NA>              2                 2  ...
# 3             2376  6037           <NA>              3              <NA>  ...
# 4             1312  6037           <NA>              3              <NA>  ...
#
#    assessment_year  land_value  tax_amount  census_tract_and_block  log_error  \
# ...

# %%
sns.boxplot(data-=)
# Out:
# Empty DataFrame
# ...

# %%
# Out:
#        parcelid  airconditioningtypeid  architecturalstyletypeid  \
# 1      17052889                    NaN                       NaN
# 2      14186244                    NaN                       NaN
# 3      12177905                    NaN                       NaN
# 4      12095076                    1.0                       NaN
# 5      12069064                    NaN                       NaN
# ...         ...                    ...                       ...
# 52311  11554146                    1.0                       NaN
# 52437  11000655                    NaN                       NaN
# 52439  12773139                    1.0                       NaN
# 52438  17239384                    NaN                       NaN
# 52440  12826780                    NaN                       NaN
#
#        basementsqft  bathroomcnt  bedroomcnt  buildingclasstypeid  \
# 1               NaN          1.0         2.0                  NaN
# ...
